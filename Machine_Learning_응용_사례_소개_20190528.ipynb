# %% [markdown]
# ### 전통적 통계학과 기계학습의 절차적 차이
#
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/statistics.png?raw=true" width="450" height="420" />

# %% [markdown]
# ### Machine Learning의 분류
#
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/machine_learning.png?raw=true" width="600" height="420" />

# %% [markdown]
# # 기계학습과 관련된 논문

# %% [markdown]
# ### Predicting Cardiovascular Risk Factors from Retinal Fundus Photographs using Deep Learning
# ### 심층 학습을 이용한 망막 안저 사진의 심혈관 위험요소 예측
#
# #### Ryan Poplin, MS$^{1}$*, Avinash V. Varadarajan, MS$^{1}$*, Katy Blumer, BS$^{1}$, Yun Liu, PhD$^{1}$, Michael V. McConnell, MD, MSEE$^{2}$, Greg S. Corrado, PhD$^{1}$, Lily Peng, MD, PhD$^{1}$**, Dale R. Webster, PhD$^{1}$**
#
# $^{1}$Google Research, Google Inc, Mountain View, CA, USA
#
# $^{2}$Verily Life Sciences, South San Francisco, CA, USA; Division of Cardiovascular Medicine, Stanford School of Medicine, Stanford, CA USA
#
# #### Published in: Nature Biomedical Engineering
# #### Published: 19 February 2018
#
# https://www.nature.com/articles/s41551-018-0195-0
#
# ---

# %% [markdown]
# ### PINNACLE(Practice Innovation and Clinical Excellence)의  심혈관 레지스트리의 연구
#
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/study.png?raw=tru" width="300" height="300" />

# %% [markdown]
# ### 주요 심혈관 위험도 평가 도구 비교
# ![mace](https://github.com/donghwanseo/joint_conference/blob/master/mace.png?raw=true)
#
# 출처 : 2013 ACC/AHA Guideline on the Assessment of Cardiovascular Risk (Goff DC, et al. Circulation 2013 Nov 12. Epub. ahead of print)
#
# >※ Reynold Risk score calculator : http://www.reynoldsriskscore.org/default.aspx

# %% [markdown]
# ### 정상 안저와 당뇨망막병증 안저
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/fundus.png?raw=true" width="350" height="150" />

# %% [markdown]
# ### → 망막 안저 사진을 이용하여 심혈관 질환 위험 평가에 필요한 변수 예측

# %% [markdown]
# ### 데이터 설명
#
# ||Development Set | | Clinical Validation Set||
# |-|-|-|-|-|
# |Characteristics|UK Biobank|EyePACS|UK Biobank|EyePACS|
# |Number of Patients|48,101|236,234|12,026|999|
# |Number of Images|96,082|1,682,938|24,008|1,958|
# |Age: Mean, years(SD)|56.8 (8.2)|53.6 (11.6)|56.9 (8.2)|54.9 (10.9)|
# |Gender (% male)|44.9|39.2|44.9|39.2|
# |Ethnicity |1.2% Black,<br/>3.4% Asian/PI,<br/>90.6% White,<br/>4.1% Other|4.9% Black,<br/>5.5% Asian/PI,<br/>7.7% White,<br/>58.1% Hispanic,<br/>1.2% Native Am,<br/>1.7% Other|1.3% Black,<br/>3.6% Asian/PI,<br/>90.1% White,<br/>4.2% Other|6.4% Black,<br/>5.7% Asian/PI,11.3% White,<br/>57.2% Hispanic,<br/>0.7% Native Am,<br/>2% Other|
# |BMI: Mean (SD|27.31 (4.78)|n/a|27.37 (4.79)|n/a|
# |Systolic BP: Mean,mmHg (SD)|136.82 (18.41)|n/a|136.89 (18.3)|n/a|
# |Diastolic BP: Mean,mmHg (SD)|81.78 (10.08)|n/a|81.76 (9.87)|n/a|
# |HbA1c: Mean, %(SD)|n/a|8.23(2.14)|n/a|8.2 (2.13)|
# |Current Smoker %| 9.53%|n/a|9.87%|n/a|

# %% [markdown]
# ### 분석 흐름도
#
# #### 1. 이미지를 통해 심혈관 위험 요인 예측
#
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/NN_1.png?raw=true" width="650" height="250" />
#
# #### 2. 이미지를 이용하여 5년 이내 심혈관 질환 발병 예측
#
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/NN_2.png?raw=true" width="500" height="350" />

# %% [markdown]
# ### 망막 안저 이미지를 이용하여 만든 모델 평가
#
# ||UK Biobank Validation Set<br/>(n=12,026 patients)||EyePACS-2K Validation Set<br/>(n=999 patients)||
# |-|-|-|-|-|
# |Predicted Risk Factor<br/>(Evaluation Metric)|Algorithm<br/>(95% CI)|Baseline|Algorithm<br/>(95% CI)|Baseline|
# |Age (MAE in years)|3.26<br/>(3.22-3.31)|7.06<br/>(6.98-7.13)|3.42<br/>(3.23-3.61)|8.48<br/>(8.07-8.90)|
# |Age (R$^{2})$|0.74<br/>(0.73-0.75)|0.00|0.82<br/>(0.79-0.84)|0|
# |Gender (AUC)|0.97<br/>(0.966-0.971)|0.50|0.97<br/>(0.96-0.98)|0.5|
# |Current Smoker(AUC)|0.71<br/>(0.70-0.73)|0.50|n/a|n/a|
# |HbA1c (MAE in %)|n/a|n/a|1.39<br/>(1.29-1.50)|1.67<br/>(1.58-1.77)|
# |HbA1c (R$^{2}$)|n/a|n/a|0.09<br/>(0.03-0.16)|0|
# |Systolic BP (MAE in mmHg)|11.35<br/>(11.18-11.51)|14.57<br/>(14.38-14.77)|n/a|n/a|
# |Systolic BP (R$^{2}$)|0.36<br/>(0.35-0.37)|0.00|n/a|n/a|
# |Diastolic BP (MAE in mmHg)|6.42<br/>(6.33-6.52)|7.83<br/>(7.73-7.94)|n/a|n/a|
# |Diastolic BP (R$^{2}$)|0.32<br/>(0.30-0.33)|0.00|n/a|n/a|
# |BMI (MAE)|3.29<br/>(3.24-3.34)|3.62<br/>(3.57-3.68)|n/a|n/a|
# |BMI (R$^{2}$)|0.13<br/>(0.11-0.14)|0.00|n/a|n/a|

# %% [markdown]
# ### 단일 망막 안저 이미지에 대한 Attention map
#
# <img src="https://github.com/donghwanseo/joint_conference/blob/master/attention_map.png?raw=true" width="500" height="360" />

# %% [markdown]
# ### 망막 안저 이미지를 통한 심혈관 질환 위험 평가
# |Model|AUC (95% CI)|
# |-|-|
# |Age only| 0.66 (0.61-0.71)|
# |Systolic blood pressure (SBP)  only| 0.66 (0.61-0.71)|
# |Body mass index (BMI)  only| 0.62 (0.56-0.67)|
# |Gender  only| 0.57 (0.53-0.62)|
# |Current smoker  only| 0.55 (0.52-0.59)|
# |Algorithm  only| 0.70 (0.65-0.74)|
# |Age + SBP + BMI + gender + current smoker| 0.72 (0.68-0.76)|
# |Algorithm + age + SBP + BMI + gender + current smoker| 0.73 (0.69-0.77)|
# |Systematic COronary Risk Evaluation (SCORE)| 0.72 (0.67-0.76)|
# |Algorithm + SCORE| 0.72 (0.67-0.76)|
#
#
# > ※ SCORE : https://www.escardio.org/Education/Practice-Tools/CVD-prevention-toolbox/SCORE-Risk-Charts

# %% [markdown]
# ### 해당 연구의 한계
# 1. 45도 각도의 영상만 사용
# 2. 망막 안저 이미지로 심혈관 질환 위험평가를 했을때, 신뢰구간의 길이가 넓음
# 3. 데이터셋에 중요한 입력 내용이 데이터 집합에서 누락
# 4.  과거 흡연 여부
